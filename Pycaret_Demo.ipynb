# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaisood08/DataNoteBooks/blob/main/Pycaret_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For 5 question Use 5 Copies of this Notebook

# %% [markdown]
# #INITILIZE

# %%
# %%capture
#@markdown <center><h3> !  important Cell  </h3></center><br>
#@markdown <center><h3>Always Run this Cell just after opening Notebook  </h3></center><br>
# !pip install pycaret;
import pandas as pd

from pycaret.datasets import get_data;

# %% [markdown]
# #Include Dataset

# %% [markdown]
# * Run Any One Cell

# %%
#@markdown <br><center><img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Google_Drive_logo.png/1024px-Google_Drive_logo.png' height="140" alt="Gdrive-logo"/></center>
#@markdown <center><h3>If You got Drive link to dataset </h3></center><br>

URL = 'https://drive.google.com/file/d/1CIwWKHJiEca4UzFT8STS5yAVyOsWYHNs/view?usp=sharing'#@param {type:"string"}
Target = "SalePrice" #@param {type:"string"}
path = 'https://drive.google.com/uc?export=download&id='+URL.split('/')[-2]
Data = pd.read_csv(path)
Data.head()
# Out:
#    Unnamed: 0  Id  MSSubClass  ... SaleType  SaleCondition  SalePrice
# 0           0   1          60  ...       WD         Normal     208500
# 1           1   2          20  ...       WD         Normal     181500
# 2           2   3          60  ...       WD         Normal     223500
# 3           3   4          70  ...       WD        Abnorml     140000
# 4           4   5          60  ...       WD         Normal     250000
#
# [5 rows x 82 columns]

# %%
#@markdown <br><center><img src='https://www.pngarts.com/files/2/Upload-Free-PNG-Image.png' height="140" alt="Gdrive-logo"/></center>
#@markdown <center><h3> Run this cell to -  </h3></center><br>
#@markdown <center><h2> Upload Local File </h2></center><br>
Target = "SalePrice" #@param {type:"string"}

from google.colab import files 
uploaded = files.upload()
name = list(uploaded.keys())

Data = pd.read_csv(name[0])
Data.head()

# %%
# %%capture
#@markdown <br><center><img src='https://avatars0.githubusercontent.com/u/58118658?s=400&v=4' height="140" alt="Gdrive-logo"/></center>
#@markdown <center><h3>If You got name and target </h3></center><br>
DATASET = "house" #@param {type:"string"}
Target = "SalePrice" #@param {type:"string"}

Data = get_data(DATASET); # DATASET IMPORT
print("Dataset Succesfully Imported -> Shape : ",dataS.shape)

# %% [markdown]
# #SetUp

# %% [markdown]
# * Data Split should be unchecked for no Split

# %%
#@markdown <center><h1>Build Model</h1></center><br>
#@markdown <center><h>Check For Datatype and Press Enter </h></center><br>

Train_Size = 0.7 #@param {type: "slider", min: 0.1, max: 0.9, step: 0.1}
Data_Split = False #@param {type:"boolean"}
Remove_Duplicates = True #@param {type:"boolean"}
if Remove_Duplicates:
  Data.drop_duplicates()

#@markdown <hr><br>
#@markdown <center><h>Normalize</h></center><br>
Normalize = False #@param {type:"boolean"}
Normalize_method = 'zscore'  #@param ["zscore", "minmax","maxabs", "robust"]

#@markdown <hr><br>
#@markdown <center><h>Feature Selection</h></center><br>
Feature_Selection = False #@param {type:"boolean"}
Feature_Selection_Threshold = 0.8 #@param {type: "slider", min: 0.1, max: 1.0,step: 0.1}
 

#@markdown <hr><br>
#@markdown <center><h>Outliers Removal</h></center><br>
Remove_Outliers = False #@param {type:"boolean"}
Outliers_Threshold = 0.05 #@param {type: "slider", min: 0.00, max: 0.90,step: 0.01}

#@markdown <hr><br>
#@markdown <center><h>Transformation</h></center><br>
Transformation = False #@param {type:"boolean"}
Transformation_Method ='yeo-johnson' #@param['yeo-johnson','quantile']

#@markdown <hr><br>
#@markdown <center><h>Principal Component Analysis</h></center><br>
PCA = False #@param {type:"boolean"}
Pca_Method = 'linear' #@param['linear','kernel','incremental']


from pycaret.regression import *
reg = setup(data = Data, target=Target ,train_size=Train_Size ,
            normalize=Normalize ,normalize_method=Normalize_method,
            feature_selection=Feature_Selection,feature_selection_threshold=Feature_Selection_Threshold,
            remove_outliers=Remove_Outliers ,outliers_threshold=Outliers_Threshold,
            transformation=Transformation ,transformation_method=Transformation_Method,
            pca=PCA ,pca_method=Pca_Method,
            data_split_shuffle=Data_Split,
            silent=True,
            use_gpu=True
            )
# Out:
#                                Description             Value
# 0                               session_id              1602
# 1                                   Target         SalePrice
# 2                            Original Data        (1460, 82)
# 3                           Missing Values              True
# 4                         Numeric Features                20
# 5                     Categorical Features                61
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set       (1021, 403)
# 10                    Transformed Test Set        (439, 403)
# 11                      Shuffle Train-Test             False
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# 14                             Fold Number                10
# 15                                CPU Jobs                -1
# 16                                 Use GPU              True
# 17                          Log Experiment             False
# 18                         Experiment Name  reg-default-name
# 19                                     USI              23a1
# 20                         Imputation Type            simple
# 21          Iterative Imputation Iteration              None
# 22                         Numeric Imputer              mean
# 23      Iterative Imputation Numeric Model              None
# 24                     Categorical Imputer          constant
# 25  Iterative Imputation Categorical Model              None
# 26           Unknown Categoricals Handling    least_frequent
# 27                               Normalize             False
# 28                        Normalize Method              None
# 29                          Transformation             False
# 30                   Transformation Method              None
# 31                                     PCA             False
# 32                              PCA Method              None
# 33                          PCA Components              None
# 34                     Ignore Low Variance             False
# 35                     Combine Rare Levels             False
# 36                    Rare Level Threshold              None
# 37                         Numeric Binning             False
# 38                         Remove Outliers             False
# 39                      Outliers Threshold              None
# 40                Remove Multicollinearity             False
# 41             Multicollinearity Threshold              None
# 42                              Clustering             False
# 43                    Clustering Iteration              None
# 44                     Polynomial Features             False
# 45                       Polynomial Degree              None
# 46                    Trignometry Features             False
# 47                    Polynomial Threshold              None
# 48                          Group Features             False
# 49                       Feature Selection             False
# 50            Features Selection Threshold              None
# 51                     Feature Interaction             False
# 52                           Feature Ratio             False
# 53                   Interaction Threshold              None
# 54                        Transform Target             False
# 55                 Transform Target Method           box-cox

# %% [markdown]
# #Best Model

# %% [markdown]
# * Round_up should be greater than 4(default) For no Round-off's

# %%
#@markdown <center><h1>Best Model</h1></center><br>
#@markdown <center><p>Default Sort = 'R2' for regression </p></center><br>

Fold = 15 #@param {type: "slider", min: 2, max: 45}
Round_Up = 10 #@param {type: "slider", min: 0, max: 20}
Sort = 'R2' #@param['AUC','MAE','MSE','RMSE','R2','RMSLE','MAPE']
Result = compare_models(fold = Fold,  round = Round_Up ,sort=Sort);
Result = pull()
# Out:
#                                     Model           MAE           MSE  \
# catboost               CatBoost Regressor  1.584510e+04  8.336428e+08
# ridge                    Ridge Regression  1.807218e+04  8.908354e+08
# lightgbm  Light Gradient Boosting Machine  1.775675e+04  9.464143e+08
# gbr           Gradient Boosting Regressor  1.774350e+04  1.037192e+09
# rf                Random Forest Regressor  1.883999e+04  1.072328e+09
# en                            Elastic Net  1.970729e+04  1.083252e+09
# omp           Orthogonal Matching Pursuit  1.754773e+04  9.904516e+08
# et                  Extra Trees Regressor  2.161045e+04  1.372092e+09
# lasso                    Lasso Regression  2.007288e+04  1.189061e+09
# br                         Bayesian Ridge  2.329133e+04  1.369250e+09
# lr                      Linear Regression  2.076478e+04  1.233719e+09
# ada                    AdaBoost Regressor  2.611070e+04  1.505220e+09
# huber                     Huber Regressor  2.691374e+04  1.660214e+09
# knn                 K Neighbors Regressor  3.023102e+04  2.097342e+09
# dt                Decision Tree Regressor  2.854800e+04  2.454771e+09
# xgboost         Extreme Gradient Boosting  0.000000e+00  0.000000e+00
# par          Passive Aggressive Regressor  5.802568e+04  7.491701e+09
# llar         Lasso Least Angle Regression  3.993623e+07  1.625249e+18
#
#                   RMSE            R2     RMSLE        MAPE  TT (Sec)
# catboost  2.677092e+04  8.800405e-01  0.129838    0.091165  6.658000
# ridge     2.854471e+04  8.584921e-01  0.157591    0.108675  0.074000
# lightgbm  2.921567e+04  8.580288e-01  0.145707    0.103262  0.208000
# gbr       2.948427e+04  8.505792e-01  0.141528    0.102599  0.918667
# rf        3.102042e+04  8.412217e-01  0.156823    0.110942  3.097333
# en        3.139462e+04  8.331181e-01  0.160053    0.116747  0.332000
# omp       2.946233e+04  8.252412e-01  0.171930    0.103639  0.036667
# et        3.589379e+04  7.895698e-01  0.177440    0.124399  3.323333
# lasso     3.311516e+04  7.893681e-01  0.231011    0.122023  0.316667
# br        3.588048e+04  7.841080e-01  0.194266    0.138348  0.349333
# lr        3.381795e+04  7.829507e-01  0.243253    0.127571  0.066000
# ada       3.777126e+04  7.657057e-01  0.208223    0.168260  0.582667
# huber     3.986531e+04  7.351780e-01  0.212146    0.161692  0.862000
# knn       4.481884e+04  6.666356e-01  0.223152    0.175693  0.272667
# dt        4.739301e+04  6.182318e-01  0.225623    0.162197  0.060000
# xgboost   0.000000e+00  0.000000e+00  0.000000    0.000000  0.022000
# par       7.680162e+04 -2.344243e-01  0.538460    0.338410  0.063333
# llar      3.291948e+08 -1.604936e+08  0.306133  725.880923  0.308000

# %% [markdown]
# #OUTPUT

# %%
print("\nBest Model Name = ",Result.iloc[0]['Model'])
print("Best Model on",Sort ," =" ,Result.iloc[0][Sort])
print("\n\nOther Information:-")
Result.iloc[0]
# Out:
# Best Model Name =  CatBoost Regressor
# Best Model on R2  = 0.8800405063
#
#
# Other Information:-
# Model       CatBoost Regressor
# MAE                    15845.1
# MSE                8.33643e+08
# RMSE                   26770.9
# R2                    0.880041
# RMSLE                 0.129838
# MAPE                 0.0911648
# TT (Sec)                 6.658
# Name: catboost, dtype: object
