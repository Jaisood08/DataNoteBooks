# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaisood08/DataNoteBooks/blob/main/Pycaret_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Include Dataset

# %%
# %%capture
#@markdown <br><center><img src='https://avatars0.githubusercontent.com/u/58118658?s=400&v=4' height="140" alt="Gdrive-logo"/></center>
#@markdown <center><h3>Intiallize Pycaret </h3></center><br>
DATASET = "boston" #@param {type:"string"}
Target = "medv" #@param {type:"string"}

# !pip install pycaret;
from pycaret.datasets import get_data;
dataS = get_data(DATASET); # DATASET IMPORT
print("Dataset Succesfully Imported -> Shape : ",dataS.shape)

# %% [markdown]
# #SetUp

# %%
#@markdown <center><h3> SEED Value  </h3></center><br>
#@markdown <center><h> Use any </h></center><br>
Set_Config = True #@param {type:"boolean"}
val=999 #@param {type:"number"}
#@markdown <hr><br>
Session_Id = False #@param {type:"boolean"}
Sval=1 #@param {type:"number"}

# %%
#@markdown <center><h1>Build Model</h1></center><br>
#@markdown <center><h>Check For Datatype and Press Enter </h></center><br>
Train_Size = 0.7 #@param {type: "slider", min: 0.1, max: 0.9, step: 0.1}

Remove_Duplicates = True #@param {type:"boolean"}
if Remove_Duplicates:
  dataS.drop_duplicates()

#@markdown <hr><br>
#@markdown <center><h>Normalize</h></center><br>
Normalize = False #@param {type:"boolean"}
Normalize_method = 'zscore'  #@param ["zscore", "minmax","maxabs", "robust"]

#@markdown <hr><br>
#@markdown <center><h>Feature Selection</h></center><br>
Feature_Selection = False #@param {type:"boolean"}
Feature_Selection_Threshold = 0.8 #@param {type: "slider", min: 0.1, max: 1.0,step: 0.1}
 

#@markdown <hr><br>
#@markdown <center><h>Outliers Removal</h></center><br>
Remove_Outliers = False #@param {type:"boolean"}
Outliers_Threshold = 0.05 #@param {type: "slider", min: 0.00, max: 0.90,step: 0.01}

#@markdown <hr><br>
#@markdown <center><h>Transformation</h></center><br>
Transformation = False #@param {type:"boolean"}
Transformation_Method ='yeo-johnson' #@param['yeo-johnson','quantile']

#@markdown <hr><br>
#@markdown <center><h>Principal Component Analysis</h></center><br>
PCA = False #@param {type:"boolean"}
Pca_Method = 'linear' #@param['linear','kernel','incremental']

if Session_Id:
  from pycaret.regression import *
  reg = setup(data = dataS, target=Target ,train_size=Train_Size ,
              normalize=Normalize ,normalize_method=Normalize_method,
              feature_selection=Feature_Selection,feature_selection_threshold=Feature_Selection_Threshold,
              remove_outliers=Remove_Outliers ,outliers_threshold=Outliers_Threshold,
              transformation=Transformation ,transformation_method=Transformation_Method,
              pca=PCA ,pca_method=Pca_Method,
              session_id = Sval
              )
else:
  from pycaret.regression import *
  reg = setup(data = dataS, target=Target ,train_size=Train_Size ,
              normalize=Normalize ,normalize_method=Normalize_method,
              feature_selection=Feature_Selection,feature_selection_threshold=Feature_Selection_Threshold,
              remove_outliers=Remove_Outliers ,outliers_threshold=Outliers_Threshold,
              transformation=Transformation ,transformation_method=Transformation_Method,
              pca=PCA ,pca_method=Pca_Method
              )
if Set_Config:
  set_config('seed',val)
# Out:
#                                Description             Value
# 0                               session_id              2488
# 1                                   Target              medv
# 2                            Original Data         (506, 14)
# 3                           Missing Values             False
# 4                         Numeric Features                11
# 5                     Categorical Features                 2
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set         (354, 21)
# 10                    Transformed Test Set         (152, 21)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# 14                             Fold Number                10
# 15                                CPU Jobs                -1
# 16                                 Use GPU             False
# 17                          Log Experiment             False
# 18                         Experiment Name  reg-default-name
# 19                                     USI              e0dd
# 20                         Imputation Type            simple
# 21          Iterative Imputation Iteration              None
# 22                         Numeric Imputer              mean
# 23      Iterative Imputation Numeric Model              None
# 24                     Categorical Imputer          constant
# 25  Iterative Imputation Categorical Model              None
# 26           Unknown Categoricals Handling    least_frequent
# 27                               Normalize             False
# 28                        Normalize Method              None
# 29                          Transformation             False
# 30                   Transformation Method              None
# 31                                     PCA             False
# 32                              PCA Method              None
# 33                          PCA Components              None
# 34                     Ignore Low Variance             False
# 35                     Combine Rare Levels             False
# 36                    Rare Level Threshold              None
# 37                         Numeric Binning             False
# 38                         Remove Outliers             False
# 39                      Outliers Threshold              None
# 40                Remove Multicollinearity             False
# 41             Multicollinearity Threshold              None
# 42                              Clustering             False
# 43                    Clustering Iteration              None
# 44                     Polynomial Features             False
# 45                       Polynomial Degree              None
# 46                    Trignometry Features             False
# 47                    Polynomial Threshold              None
# 48                          Group Features             False
# 49                       Feature Selection             False
# 50            Features Selection Threshold              None
# 51                     Feature Interaction             False
# 52                           Feature Ratio             False
# 53                   Interaction Threshold              None
# 54                        Transform Target             False
# 55                 Transform Target Method           box-cox

# %% [markdown]
# #Best Model

# %%
#@markdown <center><h1>Best Model</h1></center><br>

Fold = 10 #@param {type: "slider", min: 2, max: 45}
Round_Up = 4 #@param {type: "slider", min: 1, max: 10}
Sort = 'R2' #@param['MAE','MSE','RMSE','R2','RMSLE','MAPE']
Result = compare_models(fold = Fold,  round = Round_Up ,sort=Sort);
Result = pull()
# Out:
#                                     Model     MAE       MSE     RMSE      R2  \
# catboost               CatBoost Regressor  1.9848    7.3492   2.6730  0.9061
# et                  Extra Trees Regressor  1.9896    7.4320   2.6902  0.9051
# gbr           Gradient Boosting Regressor  2.1545    8.8219   2.8782  0.8909
# lightgbm  Light Gradient Boosting Machine  2.1899    9.1724   2.9953  0.8848
# xgboost         Extreme Gradient Boosting  2.1985    9.2464   2.9683  0.8848
# rf                Random Forest Regressor  2.2213   10.8688   3.1721  0.8712
# ada                    AdaBoost Regressor  2.4261   10.6300   3.2049  0.8620
# dt                Decision Tree Regressor  2.9990   19.2918   4.1852  0.7787
# lar                Least Angle Regression  3.1959   19.7277   4.3836  0.7542
# lr                      Linear Regression  3.2014   19.7770   4.3908  0.7534
# ridge                    Ridge Regression  3.1995   19.9354   4.4108  0.7498
# br                         Bayesian Ridge  3.2160   20.2895   4.4465  0.7455
# huber                     Huber Regressor  3.3435   23.8512   4.7841  0.7111
# lasso                    Lasso Regression  3.5462   25.0500   4.9146  0.6986
# en                            Elastic Net  3.5999   26.0078   5.0096  0.6870
# omp           Orthogonal Matching Pursuit  4.0289   32.1502   5.5716  0.5966
# knn                 K Neighbors Regressor  4.6264   45.7103   6.6697  0.4325
# llar         Lasso Least Angle Regression  6.8453   88.2847   9.3256 -0.0611
# par          Passive Aggressive Regressor  8.3191  116.0108  10.4525 -0.5164
#
#            RMSLE    MAPE  TT (Sec)
# catboost  0.1332  0.1042     2.021
# et        0.1319  0.1044     0.449
# gbr       0.1415  0.1140     0.095
# lightgbm  0.1470  0.1155     0.040
# xgboost   0.1476  0.1165     0.421
# rf        0.1498  0.1173     0.510
# ada       0.1618  0.1320     0.096
# dt        0.1978  0.1590     0.017
# lar       0.2493  0.1698     0.016
# lr        0.2531  0.1708     0.293
# ridge     0.2622  0.1720     0.014
# br        0.2565  0.1730     0.013
# huber     0.2875  0.1728     0.037
# lasso     0.2553  0.1777     0.015
# en        0.2528  0.1776     0.014
# omp       0.3275  0.2233     0.014
# knn       0.2620  0.2187     0.061
# llar      0.4056  0.3826     0.014
# par       0.5323  0.4472     0.015

# %% [markdown]
# #OUTPUT

# %%
print("\nBest Model Name = ",Result.iloc[0]['Model'])
print("Best Model on",Sort ," =" ,Result.iloc[0][Sort])
print("\n\nOther Information:-")
Result.iloc[0]
# Out:
# Best Model Name =  CatBoost Regressor
# Best Model on R2  = 0.9061
#
#
# Other Information:-
# Model       CatBoost Regressor
# MAE                     1.9848
# MSE                     7.3492
# RMSE                     2.673
# R2                      0.9061
# RMSLE                   0.1332
# MAPE                    0.1042
# TT (Sec)                 2.021
# Name: catboost, dtype: object
