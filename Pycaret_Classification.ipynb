# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaisood08/DataNoteBooks/blob/main/Pycaret_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Classification**

# %% [markdown]
# For 5 question Use 5 Copies of this Notebook

# %% [markdown]
# #INITILIZE

# %%
# %%capture
#@markdown <center><h3> !  important Cell  </h3></center><br>
#@markdown <center><h3>Always Run this Cell just after opening Notebook  </h3></center><br>
# !pip install pycaret;
import pandas as pd

from pycaret.datasets import get_data;

# %% [markdown]
# #Include Dataset

# %% [markdown]
# * Run Any One Cell

# %%
#@markdown <br><center><img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Google_Drive_logo.png/1024px-Google_Drive_logo.png' height="140" alt="Gdrive-logo"/></center>
#@markdown <center><h3>If You got Drive link to dataset </h3></center><br>

URL = 'https://drive.google.com/file/d/1UGInrFeMWrRHfrNADeO-4gezCmvDh4Cg/view?usp=sharing'#@param {type:"string"}
Target = "Class variable" #@param {type:"string"}
path = 'https://drive.google.com/uc?export=download&id='+URL.split('/')[-2]
Data = pd.read_csv(path)
Data.head()
# Out:
#    Unnamed: 0  Number of times pregnant  ...  Age (years)  Class variable
# 0           0                         6  ...           50               1
# 1           1                         1  ...           31               0
# 2           2                         8  ...           32               1
# 3           3                         1  ...           21               0
# 4           4                         0  ...           33               1
#
# [5 rows x 10 columns]

# %%
#@markdown <br><center><img src='https://www.pngarts.com/files/2/Upload-Free-PNG-Image.png' height="140" alt="Gdrive-logo"/></center>
#@markdown <center><h3> Run this cell to -  </h3></center><br>
#@markdown <center><h2> Upload Local File </h2></center><br>
Target = "SalePrice" #@param {type:"string"}

from google.colab import files 
uploaded = files.upload()
name = list(uploaded.keys())

Data = pd.read_csv(name[0])
Data.head()

# %%
# %%capture
#@markdown <br><center><img src='https://avatars0.githubusercontent.com/u/58118658?s=400&v=4' height="140" alt="Gdrive-logo"/></center>
#@markdown <center><h3>If You got name and target </h3></center><br>
DATASET = "house" #@param {type:"string"}
Target = "SalePrice" #@param {type:"string"}

Data = get_data(DATASET); # DATASET IMPORT
print("Dataset Succesfully Imported -> Shape : ",dataS.shape)

# %% [markdown]
# #SetUp

# %% [markdown]
# * Data Split should be unchecked for no Split
# * Default Session_Id is NONE - ignore it displays "Invalid number"
# * Without Session_Id random answers will come.

# %%
#@markdown <center><h1>Build Model</h1></center><br>
#@markdown <center><h>Check For Datatype and Press Enter </h></center><br>

Train_Size = 0.7 #@param {type: "slider", min: 0.1, max: 0.9, step: 0.1}
Session_Id =  None#@param {type:"number"}
Data_Split = False #@param {type:"boolean"}
Remove_Perfect_Collinearity = False #@param {type:"boolean"}

Remove_Duplicates = True #@param {type:"boolean"}
if Remove_Duplicates:
  Data = Data.drop_duplicates()

Drop_Empty = True #@param {type:"boolean"}
if Drop_Empty:
  Data = Data.dropna()

#@markdown <hr><br>
#@markdown <center><h>Normalize</h></center><br>
Normalize = False #@param {type:"boolean"}
Normalize_method = 'zscore'  #@param ["zscore", "minmax","maxabs", "robust"]

#@markdown <hr><br>
#@markdown <center><h>Feature Selection</h></center><br>
Feature_Selection = False #@param {type:"boolean"}
Feature_Selection_Threshold = 0.8 #@param {type: "slider", min: 0.1, max: 1.0,step: 0.1}
 

#@markdown <hr><br>
#@markdown <center><h>Outliers Removal</h></center><br>
Remove_Outliers = False #@param {type:"boolean"}
Outliers_Threshold = 0.05 #@param {type: "slider", min: 0.00, max: 0.90,step: 0.01}

#@markdown <hr><br>
#@markdown <center><h>Transformation</h></center><br>
Transformation = False #@param {type:"boolean"}
Transformation_Method ='yeo-johnson' #@param['yeo-johnson','quantile']

#@markdown <hr><br>
#@markdown <center><h>Principal Component Analysis</h></center><br>
PCA = False #@param {type:"boolean"}
Pca_Method = 'linear' #@param['linear','kernel','incremental']
Pca_Components = 0.99 #@param {type: "slider", min: 0.00, max: 50.50,step: 0.01}

#@markdown <hr><br>
#@markdown <center><h> Fix Imbalance </h></center><br>
#@markdown <center><h> default = smote </h></center><br>

Fix_Imbalance = False #@param {type:"boolean"}
Fix_Imbalance_Method = None #@param {type:"string"}

from pycaret.classification import *
reg = setup(data = Data, target=Target ,train_size=Train_Size ,
            normalize=Normalize ,normalize_method=Normalize_method,
            feature_selection=Feature_Selection,feature_selection_threshold=Feature_Selection_Threshold,
            remove_outliers=Remove_Outliers ,outliers_threshold=Outliers_Threshold,
            transformation=Transformation ,transformation_method=Transformation_Method,
            pca=PCA ,pca_method=Pca_Method,pca_components=Pca_Components,
            fix_imbalance =Fix_Imbalance ,fix_imbalance_method=Fix_Imbalance_Method,
            data_split_shuffle=Data_Split,
            remove_perfect_collinearity=Remove_Perfect_Collinearity,
            silent=True,
            use_gpu=True,
            session_id = Session_Id
            )
# Out:
#                                Description             Value
# 0                               session_id              5224
# 1                                   Target    Class variable
# 2                              Target Type            Binary
# 3                            Label Encoded        0: 0, 1: 1
# 4                            Original Data         (768, 10)
# 5                           Missing Values             False
# 6                         Numeric Features                 8
# 7                     Categorical Features                 1
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (537, 24)
# 12                    Transformed Test Set         (231, 24)
# 13                      Shuffle Train-Test             False
# ...

# %% [markdown]
# #Best Model

# %% [markdown]
# * Round_up should be greater than 4(default) For no Round-off's

# %%
#@markdown <center><h1>Best Model</h1></center><br>
#@markdown <center><p>Default Sort = 'Accuracy' for classification </p></center><br>

Fold = 15 #@param {type: "slider", min: 2, max: 45}
Round_Up = 10 #@param {type: "slider", min: 0, max: 20}
Sort = 'Accuracy' #@param['Accuracy','AUC','Recall','Prec.','F1','Kappa','MCC']
Result = compare_models(fold = Fold,  round = Round_Up ,sort=Sort);
Result = pull()
# Out:
#                                     Model  Accuracy       AUC    Recall  \
# ridge                    Ridge Classifier  0.750635  0.000000  0.523504
# lda          Linear Discriminant Analysis  0.746878  0.780947  0.528632
# catboost              CatBoost Classifier  0.745185  0.806867  0.566239
# lr                    Logistic Regression  0.743228  0.783514  0.528632
# rf               Random Forest Classifier  0.741323  0.788681  0.529060
# lightgbm  Light Gradient Boosting Machine  0.733968  0.782091  0.604274
# et                 Extra Trees Classifier  0.728413  0.764163  0.478632
# gbc          Gradient Boosting Classifier  0.724815  0.791675  0.535897
# ada                  Ada Boost Classifier  0.704286  0.755148  0.535897
# knn                K Neighbors Classifier  0.698624  0.722441  0.525214
# dt               Decision Tree Classifier  0.696561  0.661199  0.544017
# nb                            Naive Bayes  0.663016  0.718417  0.163248
# ...

# %% [markdown]
# #OUTPUT

# %%
print("\nBest Model Name = ",Result.iloc[0]['Model'])
print("Best Model on",Sort ," =" ,Result.iloc[0][Sort])
print("\n\nOther Information:-")
Result.iloc[0]
# Out:
# Best Model Name =  Ridge Classifier
# Best Model on Accuracy  = 0.7506349206
#
#
# Other Information:-
# Model       Ridge Classifier
# Accuracy            0.750635
# AUC                        0
# Recall              0.523504
# Prec.                0.69949
# F1                  0.593679
# Kappa               0.419962
# MCC                 0.432126
# TT (Sec)           0.0166667
# Name: ridge, dtype: object
